# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tue", "Wed", "Thur"])
my_df
# Out:
#          Mon       Tue       Wed      Thur
# 0   0.207116  0.764873 -0.004005  2.667306
# 1   0.630207  0.635765  0.591066 -0.453165
# 2   0.083419 -0.265856 -1.027787 -1.555651
# 3   0.727715  1.445329  1.024757 -1.692119
# 4  -0.609340 -1.747985  0.707623 -0.801315
# ..       ...       ...       ...       ...
# 95 -0.166127 -1.334115  0.898261 -1.386404
# 96 -1.180488 -1.332787 -0.538405  0.348355
# 97  0.523766  0.363042 -0.978068 -0.193267
# 98 -0.516523  0.612643 -1.497145 -0.291316
# 99 -0.683224  1.270887  2.155935 -0.417272
#
# [100 rows x 4 columns]

# %%
plt.hist(my_df["Wed"])
plt.show()

# %%
plt.hist(my_df["Wed"], bins = 30)
plt.show()

# %%
plt.plot(my_df)
plt.show()

# %%
my_df["Wed"].plot(kind = 'hist', bins=30)
plt.show()

# %%
my_df.abs().plot(kind = 'area',  stacked = False)
plt.show()

# %%
my_df.abs().plot(kind = 'area', alpha=0.4, title="My Awesome area plot")
plt.show()

# %%
my_df.abs().plot(kind = 'area', alpha=0.4, title="My Awesome area plot", legend=False)
plt.show()

# %%
my_df["Wed"].abs().plot(kind = 'area', alpha=0.4, title="My Awesome area plot", legend=False)
plt.show()

# %%
my_df2 = pd.DataFrame(randn(25,4), columns=["Mon", "Tue", "Wed", "Thur"])
my_df2
# Out:
#          Mon       Tue       Wed      Thur
# 0   1.182150 -1.324128  0.978002 -0.370769
# 1  -0.003777  0.719089 -0.340057  0.300604
# 2  -1.354542 -0.451406  0.012351 -0.494954
# 3  -0.265592 -1.228481 -0.445176  0.903448
# 4   0.829728 -0.991476  1.117766 -1.480652
# 5  -0.710606 -0.022209 -0.740277  0.585479
# 6  -0.713094  1.681420 -2.770837 -0.672211
# 7  -0.912071  0.275726 -0.973408 -0.867014
# 8  -1.180619 -2.272153 -0.365656  0.857572
# 9   1.019947 -1.080893  0.387458  0.530372
# 10  0.098883  0.573659 -0.223648 -1.272557
# 11  1.842408 -0.415265  0.306384 -0.690041
# 12 -0.160728 -0.612811 -1.038640 -1.409508
# 13 -1.532104 -1.167400 -0.020725 -0.749104
# 14 -1.349800 -1.390384 -0.862674 -0.460921
# 15 -0.787036 -1.120930  0.974444 -0.651860
# 16  0.964043  0.556879 -2.012209 -0.255838
# 17 -1.670866 -1.621192 -0.217373 -0.254667
# 18  0.614442 -0.738081  0.589559 -1.750942
# 19 -1.308455 -0.298602  0.927424 -0.666972
# 20 -1.296709 -0.749173  0.422697  0.773159
# ...

# %%
my_df.abs().plot(kind = 'bar')
plt.show()

# %%
my_df.abs().plot(kind = 'bar', stacked=True)
plt.show()
