# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import ReduceLROnPlateau

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Set random seed for reproducibility
torch.manual_seed(31)
np.random.seed(31)

# %%
# Load the CSV file
df = pd.read_csv('north_korea_missile_test_database.csv')

df = df.drop(columns = ["F1","Date", "Date Entered/Updated", "Other Name", "Additional Information", "Source(s)"], axis = 1, errors = "ignore")

# %%
# Clean data
df = df.replace(['Unknown', ''], np.nan)

# Clean numerical columns
for col in ['Apogee', 'Distance Travelled','Facility Latitude', 'Facility Longitude']:
    if col in df.columns:
        df[col] = df[col].astype(str).str.replace(' km', '', regex=False).str.replace(',', '', regex=False)
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Handle missing values
numerical_cols = ['Facility Latitude', 'Facility Longitude', 'Apogee', 'Distance Travelled']
categorical_cols = ["Launch Time (UTC)",'Missile Type', 'Launch Agency/Authority', 
                   'Facility Name', 'Facility Location', 'Landing Location', 
                   'Confirmation Status', 'Test Outcome']

for col in numerical_cols:
    if col in df.columns:
        df[col] = df[col].fillna(df[col].mean())

for col in categorical_cols:
    if col in df.columns:
        df[col] = df[col].fillna('Unknown')
print(df.dtypes)
df.tail(50)
# Out:
# Launch Time (UTC)           object
# Missile Name                object
# Missile Type                object
# Launch Agency/Authority     object
# Facility Name               object
# Facility Location           object
# Facility Latitude          float64
# Facility Longitude         float64
# Landing Location            object
# Apogee                     float64
# Distance Travelled         float64
# Confirmation Status         object
# Test Outcome                object
# dtype: object
#     Launch Time (UTC)  Missile Name Missile Type  \
# 85        08:44:00 PM        Scud-C         SRBM
# 86        08:58:00 PM        Scud-C         SRBM
# 87        09:35:00 PM        Nodong         MRBM
# 88        10:53:00 PM        Nodong         MRBM
# 89        10:53:00 PM        Nodong         MRBM
# 90        08:29:00 PM  Pukguksong-1         SLBM
# 91        03:13:00 AM       ER Scud         MRBM
# 92        03:13:00 AM       ER Scud         MRBM
# 93        03:13:00 AM       ER Scud         MRBM
# 94        06:33:00 PM       Musudan         IRBM
# 95        10:00:00 PM       Musudan         IRBM
# 96        10:55:00 PM  Pukguksong-2         MRBM
# 97        10:34:00 PM       ER Scud         MRBM
# 98        10:34:00 PM       ER Scud         MRBM
# 99        10:34:00 PM       ER Scud         MRBM
# 100       10:34:00 PM       ER Scud         MRBM
# 101       10:34:00 PM       ER Scud         MRBM
# 102       10:00:00 PM           NaN      Unknown
# 103       09:42:00 PM    Hwasong-12         IRBM
# 104       09:21:00 PM    Hwasong-12         IRBM
# 105       08:33:00 PM    Hwasong-12         IRBM
# 106       08:28:00 PM    Hwasong-12         IRBM
# 107       07:59:00 AM  Pukguksong-2         MRBM
# 108       08:40:00 PM   Scud-C MaRV         SRBM
# 109       12:40:00 AM    Hwasong-14         ICBM
# 110       02:42:00 PM    Hwasong-14         ICBM
# 111       09:49:00 PM   Scud-B MaRV         SRBM
# 112       10:07:00 PM   Scud-B MaRV         SRBM
# 113       10:19:00 PM   Scud-B MaRV         SRBM
# 114       08:58:00 PM    Hwasong-12         IRBM
# 115       09:57:00 PM    Hwasong-12         IRBM
# 116       06:18:00 PM    Hwasong-15         ICBM
# 117       01:54:00 AM         KN-23         SRBM
# 118           Unknown         KN-23         SRBM
# 119       07:29:00 AM         KN-23         SRBM
# 120       07:49:00 AM         KN-23         SRBM
# 121       08:34:00 PM         KN-23         SRBM
# 122       08:57:00 PM         KN-23         SRBM
# 123           Unknown         KN-23         SRBM
# 124           Unknown         KN-23         SRBM
# 125       08:34:00 PM         KN-24         SRBM
# 126       08:50:00 PM         KN-24         SRBM
# 127       11:01:00 PM         KN-24         SRBM
# 128       11:16:00 PM         KN-24         SRBM
# 129       09:45:00 PM         KN-25         SRBM
# 130       10:02:00 PM         KN-25         SRBM
# 131       09:53:00 PM         KN-25         SRBM
# 132       10:12:00 PM         KN-25         SRBM
# 133           Unknown         KN-25         SRBM
# 134       10:00:00 PM  Pukguksong-3         SLBM
#
#                                Launch Agency/Authority  \
# 85   Hwasong Artillery Units of the KPA Strategic F...
# 86   Hwasong Artillery Units of the KPA Strategic F...
# 87   Hwasong Artillery Units of the KPA Strategic F...
# 88                                             Unknown
# 89                                             Unknown
# 90                                             Unknown
# 91   Hwasong Artillery Units of the KPA Strategic F...
# 92   Hwasong Artillery Units of the KPA Strategic F...
# 93   Hwasong Artillery Units of the KPA Strategic F...
# 94                                             Unknown
# 95                                             Unknown
# 96                                             Unknown
# 97   Hwasong Artillery Units of the KPA Strategic F...
# 98   Hwasong Artillery Units of the KPA Strategic F...
# 99   Hwasong Artillery Units of the KPA Strategic F...
# 100  Hwasong Artillery Units of the KPA Strategic F...
# 101  Hwasong Artillery Units of the KPA Strategic F...
# 102                                            Unknown
# 103                                            Unknown
# 104                                            Unknown
# 105                                            Unknown
# 106                                            Unknown
# 107                                            Unknown
# 108                                            Unknown
# 109                                            Unknown
# 110                                            Unknown
# 111                                            Unknown
# 112                                            Unknown
# 113                                            Unknown
# 114                                            Unknown
# 115                                            Unknown
# 116                                            Unknown
# 117                                            Unknown
# 118                                            Unknown
# 119                                            Unknown
# 120                                            Unknown
# 121                                            Unknown
# 122                                            Unknown
# 123                                            Unknown
# 124                                            Unknown
# 125                                            Unknown
# 126                                            Unknown
# 127                                            Unknown
# 128                                            Unknown
# 129                                            Unknown
# 130                                            Unknown
# 131                                            Unknown
# 132                                            Unknown
# 133                                            Unknown
# 134                                            Unknown
#
#                           Facility Name  \
# 85                              Hwangju
# 86                              Hwangju
# 87                              Hwangju
# 88                              Hwangju
# 89                              Hwangju
# 90                       Sinpo Shipyard
# 91                              Hwangju
# 92                              Hwangju
# 93                              Hwangju
# 94                     Panghyon Airbase
# 95                     Panghyon Airbase
# 96                Kusong Testing Ground
# 97    Sohae Satellite Launching Station
# 98    Sohae Satellite Launching Station
# 99    Sohae Satellite Launching Station
# 100   Sohae Satellite Launching Station
# 101   Sohae Satellite Launching Station
# 102  Wonsan Kalma International Airport
# 103                      Sinpo Shipyard
# 104                      Sinpo Shipyard
# 105                   Pukchang Airfield
# 106         North Kusong Testing Ground
# 107                        Lake Yonpung
# 108  Wonsan Kalma International Airport
# 109                            Panghyon
# 110               Mupyong-ni Arms Plant
# 111            Kittaeryong Missile Base
# 112            Kittaeryong Missile Base
# 113            Kittaeryong Missile Base
# 114     Pyongyang International Airport
# 115     Pyongyang International Airport
# 116                     Pyongsong Field
# 117                      Hodo Peninsula
# 118                      Hodo Peninsula
# 119                              Baegun
# 120                              Baegun
# 121                      Hodo Peninsula
# 122                      Hodo Peninsula
# 123                       Kwail Airbase
# 124                       Kwail Airbase
# 125                             Hungnam
# 126                             Hungnam
# 127                            Tongchan
# 128                            Tongchan
# 129                      Sondok Airbase
# 130                      Sondok Airbase
# 127          230.000000           Confirmed      Success
# 128          230.000000           Confirmed      Success
# 129          380.000000           Confirmed      Success
# 130          380.000000           Confirmed      Success
# 131          330.000000           Confirmed      Success
# 132          330.000000           Confirmed      Success
# 133          629.103448           Confirmed      Failure
# 134          450.000000           Confirmed      Success

# %%
# Target
target = 'Missile Name'
y = df[target]
X = df.drop(columns=[target])

# %%
# Encode categoricals with LabelEncoder
label_encoders = {}
for col in categorical_cols:
    if col in X.columns:
        label = LabelEncoder()
        X[col] = label.fit_transform(X[col].astype(str))
        label_encoders[col] = label 
# Scale numerical features
scaler = StandardScaler()
X[numerical_cols] = scaler.fit_transform(X[numerical_cols])

# Encode target
label_target = LabelEncoder()
y_encoded = label_target.fit_transform(y)

# %%
# Split data: 60% train, 20% val, 20% test
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=31)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=31)

# Convert to tensors
X_train_tensor = torch.FloatTensor(X_train.values)
y_train_tensor = torch.LongTensor(y_train)
X_val_tensor = torch.FloatTensor(X_val.values)
y_val_tensor = torch.LongTensor(y_val)
X_test_tensor = torch.FloatTensor(X_test.values)
y_test_tensor = torch.LongTensor(y_test)

# %%
# Datasets
batch_size = 32  # Adjust based on dataset size
train_ds = TensorDataset(X_train_tensor, y_train_tensor)
val_ds = TensorDataset(X_val_tensor, y_val_tensor)
test_ds = TensorDataset(X_test_tensor, y_test_tensor)

# Dataloaders
train_loader = DataLoader(train_ds, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = batch_size)
test_loader = DataLoader(test_ds, batch_size = batch_size)

# %%
# Define the neural network
class MissileClassifier(nn.Module):
    def __init__(self, input_size, num_classes, h1 = 64, h2 = 32):
        super().__init__()
        self.fc1 = nn.Linear(input_size, h1)
        self.bn1 = nn.BatchNorm1d(h1) # Adding batch normalization
        self.dropout1 = nn.Dropout(0.5)  # Adding a dropout layer to regulate overfitting
        self.fc2 = nn.Linear(h1, h2)
        self.bn2 = nn.BatchNorm1d(h2)
        self.dropout2 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(h2, num_classes)
       
          
    def forward(self, x):
        x = torch.relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)
        x = torch.relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)
        return self.fc3(x)

input_size = X.shape[1]
num_classes = len(label_target.classes_)
model = MissileClassifier(input_size, num_classes)

# %%
# Loss with class weights, optimizer with weight decay, scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
# Training loop
epochs = 100  
losses = []
for epoch in range(epochs):
    model.train()
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
         # Keep track of our losses
        losses.append(loss.detach().numpy())
        loss.backward()
        optimizer.step()

       
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            val_loss += criterion(outputs, labels).item()
    val_loss /= len(val_loader)
    
    if epoch % 10 == 0:
        print(f'Epoch {epoch}/{epochs}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch 0/100, Val Loss: 3.2936
# Epoch 10/100, Val Loss: 2.7092
# Epoch 20/100, Val Loss: 2.4883
# Epoch 30/100, Val Loss: 2.3751
# Epoch 40/100, Val Loss: 2.3392
# Epoch 50/100, Val Loss: 2.3050
# Epoch 60/100, Val Loss: 2.2522
# Epoch 70/100, Val Loss: 2.1836
# Epoch 80/100, Val Loss: 2.1265
# Epoch 90/100, Val Loss: 2.0773

# %%
# Test the model
model.eval()
y_pred = []
y_true = []
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        y_pred.extend(predicted.numpy())
        y_true.extend(labels.numpy())

accuracy = accuracy_score(y_true, y_pred)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 74.07%
