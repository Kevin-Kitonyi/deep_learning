# %%
import pandas as  pd
import numpy as np
from numpy.random import randn

# %%
my_data = randn(4,3) #Rows and Colums
my_rows = ["A", "B", "C", "D"]
my_cols = ["Monay", "Tuesday", "Friday"]

# %%
# Create DataFrame
my_df = pd.DataFrame(my_data, my_rows, my_cols)
my_df
# Out:
#       Monay   Tuesday    Friday
# A  1.349763 -0.190326 -0.938884
# B  0.673253  0.494051 -2.156624
# C -0.275663 -0.313195  0.865137
# D  0.497121 -0.409066 -0.320555

# %%
# Import csv file
my_df2 = pd.read_csv('products-100.csv')
my_df2
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
# Pulling out rows
my_df2.loc[0]
# Out:
# Index                                                       1
# Name                     Compact Printer Air Advanced Digital
# Description     Situation organization these memory much off.
# Brand                                 Garner, Boyle and Flynn
# Category                                   Books & Stationery
# Price                                                     265
# Currency                                                  USD
# Stock                                                     774
# EAN                                             2091465262179
# Color                                             ForestGreen
# Size                                                    Large
# Availability                                        pre_order
# Internal ID                                                56
# Name: 0, dtype: object

# %%
my_df2.head(7)
# Out:
#    Index                                            Name  \
# 0      1            Compact Printer Air Advanced Digital
# 1      2                                          Tablet
# 2      3                            Smart Blender Cooker
# 3      4                    Advanced Router Rechargeable
# 4      5                    Portable Mouse Monitor Phone
# 5      6                                           Radio
# 6      7  Ultra Projector Oven Thermostat Prime Advanced
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
# 5   Character prove growth contain serious customer.
# 6  Pattern possible look necessary indicate work ...
#
# ...

# %%
my_df2.tail(7)
# Out:
#     Index                                   Name  \
# 93     94                                Scanner
# 94     95                      Ultra Radio Radio
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                          Description                        Brand  \
# 93       Draw material quickly most.        Wang, Ayala and Bowen
# 94         Shoulder red boy away if.             Maldonado-Ritter
# 95  Investment everything story buy.                 Atkinson Inc
# 96    Nature notice themselves news.                     Shea Ltd
# 97  Understand still or summer rule.                     West Ltd
# 98              Final art some push.     Bell, Gamble and Barrett
# 99        However public major baby.  Hebert, Hughes and Trujillo
#
# ...

# %%
my_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         100 non-null    int64
#  1   Name          100 non-null    object
#  2   Description   100 non-null    object
#  3   Brand         100 non-null    object
#  4   Category      100 non-null    object
#  5   Price         100 non-null    int64
#  6   Currency      100 non-null    object
#  7   Stock         100 non-null    int64
#  8   EAN           100 non-null    int64
#  9   Color         100 non-null    object
#  10  Size          100 non-null    object
#  11  Availability  100 non-null    object
#  12  Internal ID   100 non-null    int64
# dtypes: int64(5), object(8)
# memory usage: 10.3+ KB

# %%
my_df2.shape
# Out:
# (100, 13)

# %%
my_df2.Brand
# Out:
# 0         Garner, Boyle and Flynn
# 1                     Mueller Inc
# 2      Lawson, Keller and Winters
# 3              Gallagher and Sons
# 4                       Irwin LLC
#                  ...
# 95                   Atkinson Inc
# 96                       Shea Ltd
# 97                       West Ltd
# 98       Bell, Gamble and Barrett
# 99    Hebert, Hughes and Trujillo
# Name: Brand, Length: 100, dtype: object

# %%
my_df2['Color'].value_counts()
# Out:
# Color
# Cyan                4
# MidnightBlue        3
# Sienna              3
# ForestGreen         2
# MediumOrchid        2
#                    ..
# MediumAquaMarine    1
# BlueViolet          1
# Navy                1
# DeepSkyBlue         1
# OldLace             1
# Name: count, Length: 72, dtype: int64

# %%
my_df2.insert(5, "Rating",["No Rating"]*len(my_df2), True )
my_df2
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
my_df3 = my_df2.assign(InDemand=[True]*len(my_df2))
my_df3
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
 my_df2.drop("Rating", axis=1)
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
my_df2
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
my_df2.drop("Rating", axis=1, inplace=True)

# %%
my_df2.drop("Index", axis=1, inplace=True)

# %%
my_df2
# Out:
#                                      Name  \
# 0    Compact Printer Air Advanced Digital
# 1                                  Tablet
# 2                    Smart Blender Cooker
# 3            Advanced Router Rechargeable
# 4            Portable Mouse Monitor Phone
# ..                                    ...
# 95                                 Router
# 96     Fast Thermostat Microphone Scooter
# 97  Eco Heater Toaster Stove Silent Sense
# 98               Clean Blender Scale Lite
# 99                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ..                                                ...
# 95                   Investment everything story buy.
# ...

# %%
my_df2.iloc[3]
# Out:
# Name               Advanced Router Rechargeable
# Description     For force gas energy six laugh.
# Brand                        Gallagher and Sons
# Category                     Kitchen Appliances
# Price                                       121
# Currency                                    USD
# Stock                                       896
# EAN                               3879177514583
# Color                                 PaleGreen
# Size                                          L
# Availability                       discontinued
# Internal ID                                  31
# Name: 3, dtype: object

# %%
my_df2.loc[3, "Name"]
# Out:
# 'Advanced Router Rechargeable'

# %%
my_df2.loc[[1,3,8,10], ["Brand", "Price", "Currency"]]
# Out:
#                            Brand  Price Currency
# 1                    Mueller Inc    502      USD
# 3             Gallagher and Sons    121      USD
# 8   Edwards, Odonnell and Conley    454      USD
# 10                    Russo-West    257      USD

# %%
my_df2 == "Black"
# Out:
#      Name  Description  Brand  Category  Price  Currency  Stock    EAN  Color  \
# 0   False        False  False     False  False     False  False  False  False
# 1   False        False  False     False  False     False  False  False   True
# 2   False        False  False     False  False     False  False  False  False
# 3   False        False  False     False  False     False  False  False  False
# 4   False        False  False     False  False     False  False  False  False
# ..    ...          ...    ...       ...    ...       ...    ...    ...    ...
# 95  False        False  False     False  False     False  False  False  False
# 96  False        False  False     False  False     False  False  False  False
# 97  False        False  False     False  False     False  False  False  False
# 98  False        False  False     False  False     False  False  False  False
# 99  False        False  False     False  False     False  False  False  False
#
# ...

# %%
my_df2[my_df2 == "Black"]
# Out:
#    Name Description Brand Category  Price Currency  Stock  EAN  Color Size  \
# 0   NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 1   NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN  Black  NaN
# 2   NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 3   NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 4   NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# ..  ...         ...   ...      ...    ...      ...    ...  ...    ...  ...
# 95  NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 96  NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 97  NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 98  NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
# 99  NaN         NaN   NaN      NaN    NaN      NaN    NaN  NaN    NaN  NaN
#
#    Availability  Internal ID
# 0           NaN          NaN
# ...

# %%
my_df2[my_df2 == "Black"]["Color"]
# Out:
# 0       NaN
# 1     Black
# 2       NaN
# 3       NaN
# 4       NaN
#       ...
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
# Name: Color, Length: 100, dtype: object

# %%
my_df2[my_df2["Color"] == "Cyan"]
# Out:
#                                       Name  \
# 18             Eco Freezer Powerbank Watch
# 51  Rechargeable Tablet Plus Portable Mini
# 65                               Treadmill
# 84                           Fast Keyboard
#
#                                     Description  \
# 18  Of price visit interesting enter three set.
# 51                   Expect question how sound.
# 65                        Vote only run modern.
# 84              Success other institution fear.
#
#                              Brand           Category  Price Currency  Stock  \
# 18     Pruitt, Higgins and Barnett  Cleaning Supplies    340      USD    618
# 51                 Mooney-Gonzales         Fragrances    820      USD    535
# 65  Frost, Christensen and Burnett   Women's Clothing    731      USD    744
# 84                       Lewis Ltd   Camping & Hiking    998      USD     10
#
#               EAN Color        Size   Availability  Internal ID
# ...

# %%
my_df2[(my_df2["Color"] == "Cyan") & (my_df2["Availability"] == "limited_stock")]
# Out:
#                            Name                                  Description  \
# 18  Eco Freezer Powerbank Watch  Of price visit interesting enter three set.
# 84                Fast Keyboard              Success other institution fear.
#
#                           Brand           Category  Price Currency  Stock  \
# 18  Pruitt, Higgins and Barnett  Cleaning Supplies    340      USD    618
# 84                    Lewis Ltd   Camping & Hiking    998      USD     10
#
#               EAN Color      Size   Availability  Internal ID
# 18  6340907128242  Cyan         S  limited_stock           21
# 84  3163238295239  Cyan  50x70 cm  limited_stock           64

# %%
my_df2[(my_df2["Color"] == "Cyan") | (my_df2["Availability"] == "limited_stock")]
# Out:
#                                       Name  \
# 15              Automatic Watch Lite Sense
# 18             Eco Freezer Powerbank Watch
# 25            Mini Iron Drone Wireless Pro
# 27             Wireless Webcam Stove Grill
# 30               Silent Printer Fan Shaver
# 32          Advanced Microphone Cooler Eco
# 40                        Silent Dock Fast
# 42              Rechargeable Projector Pro
# 45                Digital Stove Silent Pro
# 47                                   Clock
# 51  Rechargeable Tablet Plus Portable Mini
# 65                               Treadmill
# 69         Compact Mouse Mouse Router Mini
# 84                           Fast Keyboard
# 88                      Fast Vacuum Cooler
# 95                                  Router
# 97   Eco Heater Toaster Stove Silent Sense
# 98                Clean Blender Scale Lite
# 99                              Smart Lamp
#
#                                           Description  \
# ...

# %%
my_df3.drop("Index", axis=1, inplace=True)

# %%
my_df3["Condition"] = ["Good"]*len(my_df3)
my_df3
# Out:
#                                      Name  \
# 0    Compact Printer Air Advanced Digital
# 1                                  Tablet
# 2                    Smart Blender Cooker
# 3            Advanced Router Rechargeable
# 4            Portable Mouse Monitor Phone
# ..                                    ...
# 95                                 Router
# 96     Fast Thermostat Microphone Scooter
# 97  Eco Heater Toaster Stove Silent Sense
# 98               Clean Blender Scale Lite
# 99                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ..                                                ...
# 95                   Investment everything story buy.
# ...

# %%
stuff = { "A":[1,2,3], "B":[4,5,6], "C":[7,8,9], "D":[10,11,12]}
my_df4 = pd.DataFrame(stuff)
my_df4
# Out:
#    A  B  C   D
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12
